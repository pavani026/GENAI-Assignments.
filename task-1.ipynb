# %% [markdown]
# ## Day1 task-1

# %%
#1 User Login Check
correct_username= "admin"
correct_password= "1234"
#user input
username = input("Enter username:")
username = input("Enter password:")
#check logic
if username ==correct_username and password ==corect_password:
    print("Login succesful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: pavani
# Enter password: korivi
# Invalid Credentials

# %%
# 2 Pass / Fail Analyzer
marks = [45, 78, 90, 33, 60]
pass_count = 0
fail_count = 0
# check each mark
for mark in marks:
    if mark >= 50:
        pass_count +=1
    else:
        fail_count +=1
# final result
print("Total Students :", len(marks))
print("Passed Students:", pass_count)
print("Failed Students:", fail_count)
# Out:
# Total Students : 5
# Passed Students: 3
# Failed Students: 2

# %%
# 3 Simple Data Cleaner
names = [" Alice ", "bob", " CHARLIE "]
cleaned_names = []
# clean each name
for name in names:
    cleaned = name.strip().lower()   # remove spaces + lowercase
    cleaned_names.append(cleaned)

print("Cleaned Names:", cleaned_names)
# Out:
# Cleaned Names: ['alice', 'bob', 'charlie']

# %%
#4. Message Length Analyzer
messages = ["Hi", "Welcome to the platform", "OK"]
for msg in messages:
    length = len(msg)
    print(f"Message: '{msg}' | Length: {length}")
    # flag long messages
    if length > 10:
        print("Long Message Detected")
# Out:
# Message: 'Hi' | Length: 2
# Message: 'Welcome to the platform' | Length: 23
# Long Message Detected
# Message: 'OK' | Length: 2

# %%
#5. Error Message Detector
logs = ["INFO", "ERROR", "WARNING", "ERROR"]
error_count = 0
# count errors
for log in logs:
    if log == "ERROR":
        error_count += 1
print("Total ERROR messages:", error_count)
# Out:
# Total ERROR messages: 2
